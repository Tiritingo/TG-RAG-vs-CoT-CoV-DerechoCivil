# %% [markdown]
# ## Fase 1: Preparación del Corpus y Línea Base RAG Estándar

# %%
# !pip install -q langchain langchain-core langchain-community langchain-text-splitters \
langchain-groq langchain-huggingface langchain-chroma chromadb sentence-transformers \
pypdf ragas gradio scipy striprtf langgraph langchain-google-genai
print("Dependencias instaladas")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 45.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 69.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.5/466.5 kB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 119.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 96.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 27.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 85.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.9/353.9 kB 33.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.43.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.43.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.43.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.43.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.43.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.43.0 which is incompatible.
# Dependencias instaladas

# %%
from google.colab import drive
drive.mount('/content/drive')

print("Drive montado correctamente")
# Out:
# Mounted at /content/drive
# Drive montado correctamente

# %%
import os
import re
import shutil
import logging
import chromadb
import pandas as pd
import time

from pathlib import Path
from typing import TypedDict
from tqdm.notebook import tqdm
from google.colab import userdata

from langchain_core.documents import Document
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

from langgraph.graph import StateGraph, END

logging.getLogger("pypdf").setLevel(logging.ERROR)

print("Imports OK")
# Out:
# /tmp/ipykernel_701/2608852746.py:15: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Imports OK

# %%
CORPUS_PATH = "/content/drive/MyDrive/TG_Maestria/01_Corpus_Raw/"
VECTOR_LOCAL = "/content/vectorstore/"
VECTOR_DRIVE = "/content/drive/MyDrive/TG_Maestria/02_Vectorstore/"
RESULTS_PATH = "/content/drive/MyDrive/TG_Maestria/03_Results/"

for p in [VECTOR_LOCAL, VECTOR_DRIVE, RESULTS_PATH]:
    os.makedirs(p, exist_ok=True)

print("Rutas configuradas")
print("CORPUS_PATH:", CORPUS_PATH)
# Out:
# Rutas configuradas
# CORPUS_PATH: /content/drive/MyDrive/TG_Maestria/01_Corpus_Raw/

# %%
emb = HuggingFaceEmbeddings(
    model_name="intfloat/multilingual-e5-large",
    model_kwargs={"device": "cuda"},
    encode_kwargs={"normalize_embeddings": True}
)

print("Embeddings listos")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/160k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/201 [00:00<?, ?B/s]
# Embeddings listos

# %%
CARPETAS_SENTENCIAS = {
    "Sentencias", "sentencias",
    "Jurisprudencia", "jurisprudencia",
    "Corte_Constitucional", "corte_constitucional"
}

def limpiar_norma_markdown(texto: str) -> str:
    texto = texto.replace("\ufeff", "")
    texto = re.sub(r"\n{3,}", "\n\n", texto)
    texto = re.sub(r"[ \t]+", " ", texto)
    return texto.strip()

def limpiar_sentencia(texto: str) -> str:
    patrones_inicio = [
        r"\bCONSIDERACIONES\b",
        r"\bCONSIDERACIÓN\b",
        r"\bFUNDAMENTOS\b",
        r"\bDE LA DECISIÓN\b",
        r"\bCONSIDERACIONES DE LA CORTE\b"
    ]

    inicio_idx = None
    for patron in patrones_inicio:
        m = re.search(patron, texto, flags=re.IGNORECASE)
        if m:
            inicio_idx = m.start()
            break

    if inicio_idx is None:
        inicio_idx = 0

    fin_idx = len(texto)
    mfin = re.search(
        r"Cópiese|Notifíquese|Devuélvase|CÚMPLASE|Cúmplase",
        texto[inicio_idx:],
        flags=re.IGNORECASE
    )

    if mfin:
        fin_idx = inicio_idx + mfin.end() + 500

    texto = texto[inicio_idx:fin_idx]
    texto = re.sub(r"Firmado electrónicamente.*?(?=[A-ZÁÉÍÓÚÑ]{3,}|$)", "", texto, flags=re.DOTALL | re.IGNORECASE)
    texto = re.sub(r"Este documento fue firmado electrónicamente.*", "", texto, flags=re.DOTALL | re.IGNORECASE)
    texto = re.sub(r"Radicación\s*N[°ºo.]?\s*[-:A-Za-z0-9]+", "", texto, flags=re.IGNORECASE)
    texto = re.sub(r"^\s*\d{1,3}\s*$", "", texto, flags=re.MULTILINE)
    texto = re.sub(r"\n{3,}", "\n\n", texto)

    return texto.strip()

def extraer_ley_desde_nombre(nombre_archivo: str) -> str:
    m = re.search(r"ley[_\-\s]?(\d+)", nombre_archivo.lower())
    return m.group(1) if m else "desconocida"

def parse_markdown_articulos(texto: str, fuente: str, categoria: str):
    texto = limpiar_norma_markdown(texto)
    partes = re.split(r"(?m)^##\s+Artículo\s+(\d+)\s*$", texto)
    docs = []

    if len(partes) < 3:
        return docs

    encabezado_general = partes[0].strip()
    ley = extraer_ley_desde_nombre(Path(fuente).stem)

    for i in range(1, len(partes), 2):
        num_articulo = partes[i].strip()
        bloque = partes[i + 1].strip()

        bloque = re.sub(r"(?m)^---\s*$", "", bloque).strip()
        lineas = [l.strip() for l in bloque.splitlines() if l.strip()]
        if not lineas:
            continue

        encabezado_articulo = lineas[0]
        contenido = "\n".join(lineas)

        texto_doc = f"Artículo {num_articulo}\n{contenido}"
        if encabezado_general:
            texto_doc = f"{encabezado_general}\n\n{texto_doc}"

        metadata = {
            "tipo": "norma",
            "formato": "md",
            "categoria": categoria,
            "fuente": Path(fuente).stem,
            "archivo": Path(fuente).name,
            "ley": ley,
            "num_articulo": num_articulo,
            "encabezado": encabezado_articulo
        }

        docs.append(
            Document(
                page_content="passage: " + texto_doc,
                metadata=metadata
            )
        )

    return docs

print("Funciones de limpieza y parser listas")
# Out:
# Funciones de limpieza y parser listas

# %%
def detectar_categoria_y_tipo(archivo: Path):
    partes = [p.name for p in archivo.parents]

    if "Corte_Constitucional" in partes:
        categoria = "Corte_Constitucional"
    elif "Sentencias" in partes:
        categoria = "Sentencias"
    elif "sentencias" in partes:
        categoria = "sentencias"
    elif "Jurisprudencia" in partes:
        categoria = "Jurisprudencia"
    elif "jurisprudencia" in partes:
        categoria = "jurisprudencia"
    else:
        categoria = archivo.parent.name

    tipo = "sentencia" if any(p in CARPETAS_SENTENCIAS for p in partes) else "norma"
    return categoria, tipo

def extraer_texto_rtf(ruta_rtf: str) -> str:
    from striprtf.striprtf import rtf_to_text

    with open(ruta_rtf, "r", encoding="utf-8", errors="ignore") as f:
        contenido = f.read()

    texto = rtf_to_text(contenido)
    texto = re.sub(r"\n{3,}", "\n\n", texto)
    return texto.strip()

print("Funciones para RTF listas")
# Out:
# Funciones para RTF listas

# %%
def cargar_corpus_mixto(corpus_path: str):
    docs = []
    candidatos = [f for f in Path(corpus_path).rglob("*") if f.is_file()]
    print(f"{len(candidatos)} archivos encontrados en corpus")

    stats = {
        "ok": 0,
        "error": 0,
        "docs_md": 0,
        "paginas_pdf": 0,
        "docs_rtf": 0,
        "vacias": 0
    }

    for archivo in candidatos:
        try:
            categoria, tipo_doc = detectar_categoria_y_tipo(archivo)
            sufijo = archivo.suffix.lower()

            if sufijo == ".md":
                with open(archivo, "r", encoding="utf-8") as f:
                    texto = f.read()

                docs_md = parse_markdown_articulos(texto, str(archivo), categoria)
                docs.extend(docs_md)

                stats["ok"] += 1
                stats["docs_md"] += len(docs_md)
                print(f"[MD ] {categoria} | {archivo.name} | {len(docs_md)} artículos")

            elif sufijo == ".pdf":
                pages = PyPDFLoader(str(archivo)).load()
                paginas_utiles = []

                for p in pages:
                    p.metadata["categoria"] = categoria
                    p.metadata["fuente"] = archivo.stem
                    p.metadata["archivo"] = archivo.name
                    p.metadata["formato"] = "pdf"
                    p.metadata["tipo"] = tipo_doc

                    texto = limpiar_sentencia(p.page_content) if tipo_doc == "sentencia" else p.page_content
                    texto = texto.strip()

                    if len(texto) > 30:
                        p.page_content = "passage: " + texto
                        paginas_utiles.append(p)
                    else:
                        stats["vacias"] += 1

                docs.extend(paginas_utiles)
                stats["ok"] += 1
                stats["paginas_pdf"] += len(paginas_utiles)
                print(f"[PDF] {categoria} | {archivo.name} | {len(paginas_utiles)} páginas útiles")

            elif sufijo == ".rtf":
                texto = extraer_texto_rtf(str(archivo))
                texto = limpiar_sentencia(texto) if tipo_doc == "sentencia" else texto
                texto = texto.strip()

                if len(texto) > 30:
                    docs.append(
                        Document(
                            page_content="passage: " + texto,
                            metadata={
                                "categoria": categoria,
                                "fuente": archivo.stem,
                                "archivo": archivo.name,
                                "formato": "rtf",
                                "tipo": tipo_doc,
                                "page": 0
                            }
                        )
                    )
                    stats["docs_rtf"] += 1
                else:
                    stats["vacias"] += 1

                stats["ok"] += 1
                print(f"[RTF] {categoria} | {archivo.name} | 1 documento útil")

        except Exception as e:
            stats["error"] += 1
            print(f"Error en {archivo.name}: {e}")

    print("\nResumen de carga")
    print("Archivos procesados:", stats["ok"])
    print("Archivos con error:", stats["error"])
    print("Artículos markdown:", stats["docs_md"])
    print("Páginas PDF útiles:", stats["paginas_pdf"])
    print("Documentos RTF útiles:", stats["docs_rtf"])
    print("Páginas/documentos descartados:", stats["vacias"])

    return docs

# %%
docs_test = cargar_corpus_mixto(CORPUS_PATH)
print(f"\nTotal de documentos cargados: {len(docs_test)}")

for i, d in enumerate(docs_test[:3], 1):
    print(f"\nDocumento {i}")
    print("Metadata:", d.metadata)
    print("Texto:", d.page_content[:400])
# Out:
# 716 archivos encontrados en corpus
# [MD ] Codigo_Civil | codigo_civil_intro_rag.md | 1138 artículos
# [MD ] Codigo_Comercio | codigo_comercio_rag.md | 2037 artículos
# [MD ] Ley_1480 | ley_1480_rag.md | 58 artículos
# [MD ] Ley_222 | ley_222_rag.md | 247 artículos
# [PDF] Sentencias | sc1971_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_12_12_2022_po_790734_número_de_pr.pdf | 59 páginas útiles
# [PDF] Sentencias | sc3755_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_28_11_2022_po_789342_número_de_pr.pdf | 60 páginas útiles
# [PDF] Sentencias | sc2850_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_10_2022_po_784543_número_de_pr.pdf | 146 páginas útiles
# [PDF] Sentencias | sc2879_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_27_09_2022_po_781082_número_de_pr.pdf | 129 páginas útiles
# [PDF] Sentencias | sc2719_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_01_09_2022_po_779281_número_de_pr.pdf | 129 páginas útiles
# [PDF] Sentencias | sc963_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_01_07_2022_pon_773439_número_de_pr.pdf | 71 páginas útiles
# [PDF] Sentencias | sc487_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_04_04_2022_pon_764531_número_de_pr.pdf | 80 páginas útiles
# [PDF] Sentencias | sc041_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_09_02_2022_pon_757329_número_de_pr.pdf | 34 páginas útiles
# [PDF] Sentencias | sc5430_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_12_2021_po_752896_número_de_pr.pdf | 131 páginas útiles
# [PDF] Sentencias | sc4904_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_04_11_2021_po_749839_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc4174_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_13_10_2021_po_747572_número_de_pr.pdf | 90 páginas útiles
# [PDF] Sentencias | sc3907_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_09_2021_po_743658_número_de_pr.pdf | 63 páginas útiles
# [PDF] Sentencias | sc3375_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_01_09_2021_po_742707_número_de_pr.pdf | 55 páginas útiles
# [PDF] Sentencias | sc3644_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741668_número_de_pr.pdf | 1 páginas útiles
# [PDF] Sentencias | sc3689_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741809_número_de_pr.pdf | 62 páginas útiles
# [PDF] Sentencias | sc3674_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741820_número_de_pr.pdf | 24 páginas útiles
# [PDF] Sentencias | sc3675_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741824_número_de_pr.pdf | 43 páginas útiles
# [PDF] Sentencias | sc3712_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741958_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3666_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_742226_número_de_pr.pdf | 154 páginas útiles
# [PDF] Sentencias | sc3535_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_08_2021_po_741084_número_de_pr.pdf | 31 páginas útiles
# [PDF] Sentencias | sc2930_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_07_2021_po_736862_número_de_pr.pdf | 31 páginas útiles
# [PDF] Sentencias | sc2217_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_09_06_2021_po_732761_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2218_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_09_06_2021_po_732762_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1947_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_05_2021_po_731772_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1832_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_05_2021_po_730777_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc563_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_01_03_2021_pon_723413_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc282_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_02_2021_pon_721538_número_de_pr.pdf | 61 páginas útiles
# [PDF] Sentencias | sc005_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_01_2021_pon_720197_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3598_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sentencia_sustituti_709927_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3273_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_09_2020_po_706877_número_de_pr.pdf | 54 páginas útiles
# [PDF] Sentencias | sc1589_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_10_08_2020_po_702117_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2582_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_27_07_2020_po_700621_número_de_pr.pdf | 138 páginas útiles
# [PDF] Sentencias | sc11287_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sentencia_sustitut_494408_número_de_pr.pdf | 66 páginas útiles
# [PDF] Sentencias | sc1182_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_02_2016_po_469742_número_de_pr.pdf | 11 páginas útiles
# [PDF] Sentencias | sc1807_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_24_02_2015_po_364060_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_3103_012_1999_01957_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227858_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 05001_3103_016_2002_00007_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227854_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1171_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_04_2022_po_765134_número_de_pr.pdf | 67 páginas útiles
# [PDF] Sentencias | sc5040_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_06_12_2021_po_752755_número_de_pr.pdf | 87 páginas útiles
# [PDF] Sentencias | sc3727_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_09_2021_po_744028_número_de_pr.pdf | 42 páginas útiles
# [PDF] Sentencias | sc3632_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741676_número_de_pr.pdf | 1 páginas útiles
# [PDF] Sentencias | sc2130_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_02_06_2021_po_732270_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc4786_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_12_2020_po_716655_número_de_pr.pdf | 64 páginas útiles
# [PDF] Sentencias | sc2362_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_13_07_2022_po_774441_número_de_pr.pdf | 33 páginas útiles
# [PDF] Sentencias | sc5252_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_11_2021_po_751931_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3194_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_08_2021_po_741005_número_de_pr.pdf | 54 páginas útiles
# [PDF] Sentencias | sc7110_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_24_05_2017_po_538590_número_de_pr.pdf | 55 páginas útiles
# [PDF] Sentencias | 11001_3103_018_1999_00533_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_su_228007_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 20001_3103_003_1998_00238_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227809_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc042_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_02_2022_pon_758076_número_de_pr.pdf | 157 páginas útiles
# [PDF] Sentencias | sc5251_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_11_2021_po_751930_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc5185_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_11_2021_po_751932_número_de_pr.pdf | 82 páginas útiles
# [PDF] Sentencias | sc4856_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_02_11_2021_po_749544_número_de_pr.pdf | 46 páginas útiles
# [PDF] Sentencias | sc4126_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_30_09_2021_po_746287_número_de_pr.pdf | 54 páginas útiles
# [PDF] Sentencias | sc3604_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741665_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2411_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_17_06_2021_po_734282_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2412_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_17_06_2021_po_734283_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2354_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_16_06_2021_po_733461_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3929_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_10_2020_po_711290_número_de_pr.pdf | 25 páginas útiles
# [PDF] Sentencias | sc5679_2018_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_12_2018_po_652241_número_de_pr.pdf | 112 páginas útiles
# Error en sc12063_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sustitutiva_fecha__544646_número_de_pr.pdf: Stream has ended unexpectedly
# Error en sc15173_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_24_10_2016_p_515310_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc2506_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_02_03_2016_po_471839_número_de_pr.pdf | 58 páginas útiles
# Error en sc2307_2018_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_06_2018_po_635280_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc3663_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_22_11_2022_po_788788_número_de_pr.pdf | 48 páginas útiles
# [PDF] Sentencias | sc1170_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_22_04_2022_po_766135_número_de_pr.pdf | 34 páginas útiles
# [PDF] Sentencias | sc2500_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_23_06_2021_po_734803_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2501_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_23_06_2021_po_734809_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | ac280_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_08_02_2021_ponente__717488_número_de_pr.pdf | 23 páginas útiles
# [PDF] Sentencias | sc2221_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_13_07_2020_po_699010_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1256_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_27_05_2022_po_771078_número_de_pr.pdf | 126 páginas útiles
# [PDF] Sentencias | sc4455_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_10_2021_po_749019_número_de_pr.pdf | 45 páginas útiles
# [PDF] Sentencias | sc2906_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_29_07_2021_po_739039_número_de_pr.pdf | 61 páginas útiles
# [PDF] Sentencias | sc397_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_22_02_2021_pon_722675_número_de_pr.pdf | 84 páginas útiles
# [PDF] Sentencias | sc12743_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_24_08_2017_p_545687_número_de_pr.pdf | 75 páginas útiles
# [PDF] Sentencias | sc2215_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_09_06_2021_po_732920_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | ac3347_2020_clase_de_actuación_recurso_de_queja_tipo_de_providencia_auto_fecha_07_12_2020_ponente_ar_716856_número_de_pr.pdf | 13 páginas útiles
# [PDF] Sentencias | sc3346_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_09_2020_po_707692_número_de_pr.pdf | 40 páginas útiles
# [PDF] Sentencias | sc3251_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_09_2020_po_706880_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc10291_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_07_2017_p_542490_número_de_pr.pdf | 27 páginas útiles
# [PDF] Sentencias | sc8456_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_24_06_2016_po_489009_número_de_pr.pdf | 28 páginas útiles
# [PDF] Sentencias | sc8210_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_21_06_2016_po_487984_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 25269_3103_002_2005_00199_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_228058_número_de_pr.pdf | 0 páginas útiles
# Error en sc3678_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_742028_número_de_pr.pdf: Trailer cannot be read: 'NumberObject' object is not subscriptable
# [PDF] Sentencias | sc2929_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_07_2021_po_736861_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | ac054_2021_clase_de_actuación_incidente_de_nulidad_tipo_de_providencia_auto_fecha_21_01_2021_ponente_720003_número_de_pr.pdf | 16 páginas útiles
# [PDF] Sentencias | sc5191_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_12_2020_po_718325_número_de_pr.pdf | 69 páginas útiles
# [PDF] Sentencias | sc3365_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_21_09_2020_po_708336_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3467_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_21_09_2020_po_708342_número_de_pr.pdf | 33 páginas útiles
# [PDF] Sentencias | ac1605_2017_clase_de_actuación_conflicto_de_competencia_tipo_de_providencia_auto_fecha_15_03_2017_po_535233_número_de_pr.pdf | 6 páginas útiles
# [PDF] Sentencias | sc11786_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_08_2016_p_502964_número_de_pr.pdf | 51 páginas útiles
# [PDF] Sentencias | sc11197_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2015_p_429016_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3864_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_04_2015_po_393446_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | ac5941_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_29_09_2014_ponente_311313_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc11003_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_20_08_2014_p_282460_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 7326831030022004_00097_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fecha_228331_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 20001_3103_003_2007_00100_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_su_227888_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 05045_3103_001_2007_00062_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227805_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3890_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_09_2021_po_744278_número_de_pr.pdf | 33 páginas útiles
# Error en ac1740_2019_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_13_05_2019_ponente_665204_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc21801_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_12_2017_p_613875_número_de_pr.pdf | 85 páginas útiles
# Error en 11001_31_03_042_2006_00453_01_clase_de_actuación_reposicion_tipo_de_providencia_auto_fecha_27_02_201_210568_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | 11001_3103_032_2002_00083_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_su_227890_número_de_pr.pdf | 46 páginas útiles
# [PDF] Sentencias | sc3159_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_30_09_2022_po_781497_número_de_pr.pdf | 55 páginas útiles
# [PDF] Sentencias | sc4425_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_05_10_2021_po_746797_número_de_pr.pdf | 58 páginas útiles
# [PDF] Sentencias | sc4232_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_23_09_2021_po_745418_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc4204_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_22_09_2021_po_745206_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3631_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741667_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3253_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_04_08_2021_po_739481_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2749_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_07_2021_po_736094_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1043_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_05_04_2021_po_726450_número_de_pr.pdf | 71 páginas útiles
# [PDF] Sentencias | sc1084_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_05_04_2021_po_726585_número_de_pr.pdf | 36 páginas útiles
# [PDF] Sentencias | sc299_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_02_2021_pon_721540_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc010_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_21_01_2021_pon_720034_número_de_pr.pdf | 32 páginas útiles
# [PDF] Sentencias | sc5141_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_16_12_2020_po_717717_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc5142_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_16_12_2020_po_717718_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc4066_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_10_2020_po_711860_número_de_pr.pdf | 35 páginas útiles
# [PDF] Sentencias | sc3893_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_10_2020_po_711485_número_de_pr.pdf | 43 páginas útiles
# [PDF] Sentencias | sc3367_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_21_09_2020_po_708338_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc780_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_10_03_2020_pon_691929_número_de_pr.pdf | 163 páginas útiles
# Error en sc1819_2019_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_28_05_2019_po_665624_número_de_pr.pdf: Stream has ended unexpectedly
# Error en sc15032_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_22_09_2017_p_556328_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc8453_2016_clase_de_actuación_reconocimiento_de_laudo_arbitral_tipo_de_providencia_sentencia_fecha__489008_número_de_pr.pdf | 44 páginas útiles
# [PDF] Sentencias | sc2068_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_22_02_2016_po_471330_número_de_pr.pdf | 32 páginas útiles
# Error en sc11822_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_03_09_2015_p_432194_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc6709_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_28_05_2015_po_402382_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | ac6657_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_29_10_2014_ponente_309591_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc12112_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_09_2014_p_289241_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc10297_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_05_08_2014_p_273543_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 245227_número_de_proceso_11001_3103_027_1998_37459_01_clase_de_actuación_recurso_de_casación_tipo_de_13_09_2013_ponente_.pdf | 0 páginas útiles
# Error en 11001_3103_016_2003_00821_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_2_204901_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | 1100131030022001_01451_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fecha_228005_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_3103_010_2000_00155_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227806_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc575_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_04_04_2022_pon_764568_número_de_pr.pdf | 67 páginas útiles
# [PDF] Sentencias | sc5473_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_16_12_2021_po_754132_número_de_pr.pdf | 55 páginas útiles
# [PDF] Sentencias | sc3687_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_742061_número_de_pr.pdf | 56 páginas útiles
# [PDF] Sentencias | sc001_2021_clase_de_actuación_recurso_de_revisión_tipo_de_providencia_sentencia_fecha_18_01_2021_pon_719843_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc5176_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_12_2020_po_718493_número_de_pr.pdf | 57 páginas útiles
# [PDF] Sentencias | ac3596_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_15_12_2020_ponente_717888_número_de_pr.pdf | 19 páginas útiles
# [PDF] Sentencias | sc002_2018_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_12_01_2018_pon_621111_número_de_pr.pdf | 79 páginas útiles
# [PDF] Sentencias | sc19903_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_29_11_2017_p_591610_número_de_pr.pdf | 59 páginas útiles
# [PDF] Sentencias | sc5533_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_24_04_2017_po_535021_número_de_pr.pdf | 41 páginas útiles
# Error en sc5207_2017_clase_de_actuación_recurso_de_anulación_de_laudo_arbitral_tipo_de_providencia_sentencia__534564_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc8219_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_20_06_2016_po_488470_número_de_pr.pdf | 68 páginas útiles
# [PDF] Sentencias | sc5885_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sentencia_sustituti_483811_número_de_pr.pdf | 49 páginas útiles
# Error en sc9722_2015_clase_de_actuación_recurso_de_revisión_tipo_de_providencia_sentencia_fecha_18_08_2015_po_428460_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 1100102030002012_00310_00_clase_de_actuación_recurso_de_queja_tipo_de_providencia_auto_fecha_06_03_2_206536_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_3103_007_2004_00457_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_2_204872_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 1100102030002012_00214_00_clase_de_actuación_conflicto_de_competencia_tipo_de_providencia_auto_fecha_211434_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | 11001_3103_005_2000_01474_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_228333_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_3103_001_1985_00134_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227783_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 54001_3103_004_2004_00206_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227784_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_3103_025_2001_00457_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_213319_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | obligaciones_a_plazo.pdf | 59 páginas útiles
# [PDF] Sentencias | sc3149_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_28_07_2021_po_738758_número_de_pr.pdf | 0 páginas útiles
# Error en sc008_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_01_2021_pon_719962_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc003_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_01_2021_pon_719173_número_de_pr.pdf | 96 páginas útiles
# [PDF] Sentencias | sc3728_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_08_2021_po_742056_número_de_pr.pdf | 55 páginas útiles
# [PDF] Sentencias | sc3460_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_08_2021_po_741106_número_de_pr.pdf | 68 páginas útiles
# [PDF] Sentencias | sc2905_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_29_07_2021_po_738974_número_de_pr.pdf | 59 páginas útiles
# [PDF] Sentencias | sc1929_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_05_2021_po_731641_número_de_pr.pdf | 24 páginas útiles
# [PDF] Sentencias | sc1731_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_05_2021_po_730776_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1066_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_05_04_2021_po_726587_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc292_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_02_2021_pon_721535_número_de_pr.pdf | 62 páginas útiles
# [PDF] Sentencias | sc5125_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_12_2020_po_717704_número_de_pr.pdf | 89 páginas útiles
# [PDF] Sentencias | sc5025_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_12_2020_po_717248_número_de_pr.pdf | 31 páginas útiles
# [PDF] Sentencias | sc3930_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_10_2020_po_711293_número_de_pr.pdf | 69 páginas útiles
# [PDF] Sentencias | sc2769_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_31_08_2020_po_702224_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc562_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_27_02_2020_pon_691156_número_de_pr.pdf | 105 páginas útiles
# [PDF] Sentencias | sc4966_2019_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_11_2019_po_683402_número_de_pr.pdf | 70 páginas útiles
# [PDF] Sentencias | sc2202_2019_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_20_06_2019_po_667855_número_de_pr.pdf | 68 páginas útiles
# Error en sc5686_2018_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_12_2018_po_651942_número_de_pr.pdf: Stream has ended unexpectedly
# Error en sc4750_2018_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_31_10_2018_po_647628_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc2107_2018_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_12_06_2018_po_634132_número_de_pr.pdf | 71 páginas útiles
# [PDF] Sentencias | sc003_2018_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_12_01_2018_pon_620620_número_de_pr.pdf | 42 páginas útiles
# [PDF] Sentencias | sc9193_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sentencia_sustituti_541168_número_de_pr.pdf | 135 páginas útiles
# [PDF] Sentencias | ac1600_2017_clase_de_actuación_recurso_de_queja_tipo_de_providencia_auto_fecha_15_03_2017_ponente_ál_534450_número_de_pr.pdf | 13 páginas útiles
# [PDF] Sentencias | sc1815_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_02_2017_po_527564_número_de_pr.pdf | 80 páginas útiles
# [PDF] Sentencias | sc18614_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_12_2016_p_524597_número_de_pr.pdf | 67 páginas útiles
# [PDF] Sentencias | sc18146_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_12_2016_p_523244_número_de_pr.pdf | 90 páginas útiles
# [PDF] Sentencias | sc17723_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_12_2016_p_523013_número_de_pr.pdf | 65 páginas útiles
# [PDF] Sentencias | sc15996_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sustitutiva_fecha__522327_número_de_pr.pdf | 59 páginas útiles
# [PDF] Sentencias | sc16690_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sustitutiva_fecha__517513_número_de_pr.pdf | 64 páginas útiles
# Error en sc14426_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_10_2016_p_514206_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc13925_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_30_09_2016_p_513470_número_de_pr.pdf | 157 páginas útiles
# [PDF] Sentencias | sc12994_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_09_2016_p_505705_número_de_pr.pdf | 4 páginas útiles
# Error en sc11770_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_08_2016_p_502959_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc7814_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_06_2016_po_486274_número_de_pr.pdf | 29 páginas útiles
# [PDF] Sentencias | sc7824_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_06_2016_po_487350_número_de_pr.pdf | 50 páginas útiles
# [PDF] Sentencias | ac481_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_04_02_2016_ponente__469896_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc17161_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_12_2015_p_465876_número_de_pr.pdf | 22 páginas útiles
# [PDF] Sentencias | sc17096_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_11_12_2015_p_465871_número_de_pr.pdf | 42 páginas útiles
# [PDF] Sentencias | sc13630_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_07_10_2015_p_446604_número_de_pr.pdf | 66 páginas útiles
# [PDF] Sentencias | sc12018_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_09_09_2015_p_432604_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1806_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_24_02_2015_po_364208_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc038_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_02_02_2015_pon_356560_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc17175_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_16_12_2014_p_332849_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc10261_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_04_08_2014_p_272373_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc9121_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_07_2014_po_264037_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 245864_número_de_proceso_1100131030322009_00392_01_clase_de_actuación_recurso_de_casación_tipo_de_pr_21_10_2013_ponente_.pdf | 0 páginas útiles
# [PDF] Sentencias | 240689_número_de_proceso_7600131030092006_00094_01_clase_de_actuación_recurso_de_casación_tipo_de_pr_18_12_2012_ponente_.pdf | 0 páginas útiles
# [PDF] Sentencias | 5400131030042004_00032_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_10_0_211445_número_de_pr.pdf | 0 páginas útiles
# Error en 66001_3103_005_2007_00057_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_0_211444_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 54498_31_03_002_2005_00003_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha__211257_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 73268_31_03_001_2009_00075_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha__211258_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_31_03_001_2007_00104_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha__211259_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 73449_3103_001_2006_00049_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_0_211252_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 1100131030032007_00461_01_clase_de_actuación_aclaracion_sentencia_tipo_de_providencia_auto_fecha_30__211251_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_02_03_000_2012_00636_00_clase_de_actuación_conflicto_de_competencia_tipo_de_providencia_auto_f_211248_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_0203_000_2008_01381_00_clase_de_actuación_exequatur_tipo_de_providencia_auto_fecha_18_04_2012__210237_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_02_03_000_2012_00440_00_clase_de_actuación_conflicto_de_competencia_tipo_de_providencia_auto_f_210589_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_3103_032_2008_00424_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_1_209467_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_0203_000_2011_00521_00_clase_de_actuación_procesos_de_agentes_diplomaticos_tipo_de_providencia_210593_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 1100102030002011_02430_00_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_21_0_209458_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 66001_3103_001_2007_00055_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_1_206631_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_31_03_015_1999_01424_00_clase_de_actuación_reposicion_tipo_de_providencia_auto_fecha_29_02_201_204896_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 13001_3103_005_2002_00602_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_2_206497_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 23001_31_03_001_2001_00104_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha__206541_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_0203_000_2011_02466_00_clase_de_actuación_suplica_tipo_de_providencia_auto_fecha_22_02_2012_po_207772_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 203066_número_de_proceso_1100131030382006_00016_01_clase_de_actuación_reposicion_tipo_de_providencia_21_02_2012_ponente_.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc5106_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sentencia_sustituti_753946_número_de_pr.pdf | 64 páginas útiles
# Error en 23001_3103_003_2006_00243_01_clase_de_actuación_adicion_tipo_de_providencia_auto_fecha_05_03_2012_po_206587_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc3889_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_09_2021_po_743648_número_de_pr.pdf | 36 páginas útiles
# [PDF] Sentencias | sc2498_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_23_06_2021_po_734785_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc2415_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_17_06_2021_po_734284_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc4649_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_11_2020_po_716978_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_0203_000_2009_00068_00_clase_de_actuación_recurso_de_revision_tipo_de_providencia_sentencia_fe_213330_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3919_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_09_2021_po_743740_número_de_pr.pdf | 58 páginas útiles
# [PDF] Sentencias | sc3462_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_08_2021_po_741109_número_de_pr.pdf | 79 páginas útiles
# [PDF] Sentencias | sc3148_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_28_07_2021_po_738755_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3928_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_10_2020_po_711291_número_de_pr.pdf | 31 páginas útiles
# Error en sc16785_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_17_10_2017_p_558437_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | ac4858_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_02_08_2017_ponente_554769_número_de_pr.pdf | 98 páginas útiles
# [PDF] Sentencias | sc451_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_01_2017_pon_525744_número_de_pr.pdf | 48 páginas útiles
# [PDF] Sentencias | 41001_3103_002_2002_00329_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_228339_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc3654_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_08_2021_po_741815_número_de_pr.pdf | 39 páginas útiles
# [PDF] Sentencias | sc5131_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_12_2020_po_717705_número_de_pr.pdf | 31 páginas útiles
# [PDF] Sentencias | sc3941_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_19_10_2020_po_711611_número_de_pr.pdf | 140 páginas útiles
# [PDF] Sentencias | sc6315_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_09_05_2017_po_536772_número_de_pr.pdf | 121 páginas útiles
# Error en 2530731030022005_00175_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_10_0_207971_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | 1100131030142001_01489_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fecha_228329_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_3103_032_2001_00847_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_su_227895_número_de_pr.pdf | 50 páginas útiles
# [PDF] Sentencias | 13430_3103_002_2004_00359_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227857_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc4063_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_10_2020_po_711858_número_de_pr.pdf | 18 páginas útiles
# [PDF] Sentencias | sc917_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_09_2020_pon_707695_número_de_pr.pdf | 39 páginas útiles
# Error en sc788_2018_clase_de_actuación_recurso_de_revisión_tipo_de_providencia_sentencia_fecha_22_03_2018_pon_627520_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | sc15339_2017_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_28_09_2017_p_556621_número_de_pr.pdf | 32 páginas útiles
# [PDF] Sentencias | sc10152_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_07_2016_p_492466_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc8225_2016_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_22_06_2016_po_488073_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc12323_2015_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_11_09_2015_p_432707_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc12076_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_08_09_2014_p_289273_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc10326_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_05_08_2014_p_272590_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc1947_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_30_06_2022_po_773266_número_de_pr.pdf | 62 páginas útiles
# [PDF] Sentencias | sc1225_2022_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_02_06_2022_po_770900_número_de_pr.pdf | 117 páginas útiles
# [PDF] Sentencias | sc3627_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_02_11_2021_po_744547_número_de_pr.pdf | 78 páginas útiles
# [PDF] Sentencias | sc3732_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_26_08_2021_po_742059_número_de_pr.pdf | 36 páginas útiles
# [PDF] Sentencias | sc3179_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_28_07_2021_po_738751_número_de_pr.pdf | 100 páginas útiles
# [PDF] Sentencias | sc2503_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_23_06_2021_po_734810_número_de_pr.pdf | 1 páginas útiles
# [PDF] Sentencias | sc006_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_25_01_2021_pon_719959_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc007_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_sentencia_sustitutiv_719961_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | ac2828_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_auto_fecha_26_10_2020_ponente_712503_número_de_pr.pdf | 0 páginas útiles
# Error en 5001_3103_009_2004_00263_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_19_210236_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 203060_número_de_proceso_19001_3103_003_2005_00058_01_clase_de_actuación_aclaracion_sentencia_tipo_d_17_02_2012_ponente_.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | 73268_3103_002_2000_00121_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227840_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | s_037_de_1988_tipo_de_providencia_sentencia_fecha_17_02_1988_ponente_josé_alejandro_bonivento_fernan_424324_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sin_clase_de_actuación_publicación_especializada_tipo_de_providencia_publicación_especializada_fecha_776082_número_de_pr.pdf | 64 páginas útiles
# [PDF] Sentencias | sc973_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_23_03_2021_pon_726027_número_de_pr.pdf | 22 páginas útiles
# [PDF] Sentencias | sc279_2021_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_15_02_2021_pon_721541_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc5065_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_14_12_2020_po_717243_número_de_pr.pdf | 23 páginas útiles
# Error en sc877_2018_clase_de_actuación_reconocimiento_de_laudo_arbitral_tipo_de_providencia_sentencia_fecha_2_627815_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 0500131030022000_00313_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha_20_0_211436_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 1100102030002012_00332_00_clase_de_actuación_conflicto_de_competencia_tipo_de_providencia_auto_fecha_211437_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 88001_31_03_001_2006_00083_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_auto_fecha__207436_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 11001_3103_018_2004_00475_01_clase_de_actuación_reposicion_tipo_de_providencia_auto_fecha_27_02_2012_204897_número_de_pr.pdf: Stream has ended unexpectedly
# Error en 203058_número_de_proceso_15693_31_89_001_2006_00028_01_clase_de_actuación_recurso_de_casacion_tipo_d_23_02_2012_ponente_.pdf: Stream has ended unexpectedly
# Error en 203062_número_de_proceso_11001_02_03_000_2012_00241_00_clase_de_actuación_conflicto_de_competencia_t_23_02_2012_ponente_.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | 11001_3103_035_2004_00428_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_228016_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 05001_3103_005_2000_00229_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_228015_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_3103_026_2000_04366_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_227862_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 080013103004_2002_00297_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fech_227849_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 23001_3103_003_2002_00040_01_clase_de_actuación_recurso_de_casacion_tipo_de_providencia_sentencia_fe_213325_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc9493_2014_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_07_2014_po_266559_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | sc5183_2020_clase_de_actuación_recurso_de_casación_tipo_de_providencia_sentencia_fecha_18_12_2020_po_718597_número_de_pr.pdf | 57 páginas útiles
# Error en 11001_02_03_000_2012_00424_00_clase_de_actuación_conflicto_de_competencia_tipo_de_providencia_auto_f_210228_número_de_pr.pdf: Stream has ended unexpectedly
# [PDF] Sentencias | 11001_0203_000_2001_00223_00_clase_de_actuación_exequatur_tipo_de_providencia_sentencia_fecha_01_12__228048_número_de_pr.pdf | 0 páginas útiles
# [PDF] Sentencias | 11001_0203_000_2010_01111_00_clase_de_actuación_exequatur_tipo_de_providencia_sentencia_fecha_23_11__228009_número_de_pr.pdf | 0 páginas útiles
# ...
# [RTF] Corte_Constitucional | C-1123_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-733_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-544_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-496_92.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-749_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-678_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1252_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-140_22.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-485_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-060_12.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-271_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-229_16.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-815_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-854_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-197_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-334_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-196_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1204_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1006_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-796_09.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-218_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-924_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-730_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-028_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-587_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-243_19.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-702_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-478_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1046_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-241_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1008_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-046_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-309_16.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-403_94.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1025_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-189_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1276_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-923_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-943_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-444_09.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-648_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-435_94.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-819_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-573_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-022_16.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-333_11.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-454_17.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-892_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-460_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-476_98.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-749_09.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-592_12.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-726_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-313_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-987_12.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-909_12.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-973_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-830_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-583_15.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-080_15.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-150_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-574_98.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-333_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-215_93.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-004_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-1008_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-039_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-203_08.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-069_22.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-468_94.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-088_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-286_17.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-388_08.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-974_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-965_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.029_24.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-638_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-693_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-033_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-857_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-271_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-901_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-301_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-456_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-525_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-107_93.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-873_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-796_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1018_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-605_95.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-833_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-958_11.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-367_09.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-356_98.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-212_93.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1016_99.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-038_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.116_18.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-604_17.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-575_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.449_20.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1225_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-978_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-558_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-793_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-294_99.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-331_24.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-019_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-457_92.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-100_19.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-283_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-173_22.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-442_14.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-775_11.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-018_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-229_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-406_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-075_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1335_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-992_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-058_14.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1327_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-131_22.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-315_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-089_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-099_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.058_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-342_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1331_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-131_21.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-763_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-269_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1063_06.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-244_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-902_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-222_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-227_99.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-751_12.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-919_14.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-160_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-769_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-466_11.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-971_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-609_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-398_14.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.091_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-621_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-624_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-268_13.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-071_17.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.770_14.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-568_15.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-063_17.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-058_09.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-119_20.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-790_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-354_19.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-198_19.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-591_17.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-228_25.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-473_08.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.081_20.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-438_17.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-093_23.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-027_19.rtf | 1 documento útil
# [RTF] Corte_Constitucional | SU.174_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-629_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1322_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-496_12.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-029_22.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-033_18.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-471_11.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-739_99.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-154A_95.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-712_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-897_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-158_95.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-546_09.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-1641_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-054_22.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-289_97.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-191_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-481_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-628_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-081_14.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-108_19.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-034_16.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-735_98.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1205_01.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-928_11.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-407_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1212_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-717_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-643_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-471_96.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-623_99.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1384_00.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-989A_05.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-163_14.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-881_02.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-350_22.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-539_10.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-326_21.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-1205_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-451_97.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-179_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-271_07.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-141_03.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-761_15.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-263_04.rtf | 1 documento útil
# [RTF] Corte_Constitucional | T-093_15.rtf | 1 documento útil
# [RTF] Corte_Constitucional | C-726_09.rtf | 1 documento útil
#
# Resumen de carga
# Archivos procesados: 663
# Archivos con error: 53
# Artículos markdown: 3480
# Páginas PDF útiles: 8419
# Documentos RTF útiles: 411
# Páginas/documentos descartados: 5766
#
# Total de documentos cargados: 12310
#
# Documento 1
# Metadata: {'tipo': 'norma', 'formato': 'md', 'categoria': 'Codigo_Civil', 'fuente': 'codigo_civil_intro_rag', 'archivo': 'codigo_civil_intro_rag.md', 'ley': 'desconocida', 'num_articulo': '1', 'encabezado': 'ARTÍCULO 1o. <DISPOSICIONES COMPRENDIDAS>. El Código Civil comprende las disposiciones legales sustantivas que determinan especialmente los derechos de los particulares, por razón del estado de las personas, de sus bienes, obligaciones, contratos y acciones civiles.'}
# Texto: passage: # Codigo_Civil — Extracto para RAG
# > Generado el 2026-06-18 23:49
#
# Artículo 1
# ARTÍCULO 1o. <DISPOSICIONES COMPRENDIDAS>. El Código Civil comprende las disposiciones legales sustantivas que determinan especialmente los derechos de los particulares, por razón del estado de las personas, de sus bienes, obligaciones, contratos y acciones civiles.
#
# Documento 2
# Metadata: {'tipo': 'norma', 'formato': 'md', 'categoria': 'Codigo_Civil', 'fuente': 'codigo_civil_intro_rag', 'archivo': 'codigo_civil_intro_rag.md', 'ley': 'desconocida', 'num_articulo': '2', 'encabezado': 'ARTÍCULO 2o. <APLICABILIDAD>. En el presente Código Civil de la unión se reúnen las disposiciones de la naturaleza expresada en el artículo anterior que son aplicables en los asuntos de la competencia del gobierno general con arreglo a la Constitución, y en los civiles comunes de los habitantes de los territorios que él administra.'}
# Texto: passage: # Codigo_Civil — Extracto para RAG
# > Generado el 2026-06-18 23:49
#
# Artículo 2
# ARTÍCULO 2o. <APLICABILIDAD>. En el presente Código Civil de la unión se reúnen las disposiciones de la naturaleza expresada en el artículo anterior que son aplicables en los asuntos de la competencia del gobierno general con arreglo a la Constitución, y en los civiles comunes de los habitantes de los territorio
#
# Documento 3
# Metadata: {'tipo': 'norma', 'formato': 'md', 'categoria': 'Codigo_Civil', 'fuente': 'codigo_civil_intro_rag', 'archivo': 'codigo_civil_intro_rag.md', 'ley': 'desconocida', 'num_articulo': '3', 'encabezado': 'ARTÍCULO 3o. <OBLIGATORIEDAD>. Considerado este Código en su conjunto en cada uno de los títulos, capítulos y artículos de que se compone, forma la regla establecida por el legislador colombiano, a la cual es un deber de los particulares ajustarse en sus asuntos civiles, que es lo que constituye la ley o el derecho civil nacional.'}
# Texto: passage: # Codigo_Civil — Extracto para RAG
# > Generado el 2026-06-18 23:49
#
# Artículo 3
# ARTÍCULO 3o. <OBLIGATORIEDAD>. Considerado este Código en su conjunto en cada uno de los títulos, capítulos y artículos de que se compone, forma la regla establecida por el legislador colombiano, a la cual es un deber de los particulares ajustarse en sus asuntos civiles, que es lo que constituye la ley o el dere

# %%
def build_vectorstore():
    docs = cargar_corpus_mixto(CORPUS_PATH)

    if not docs:
        print("No se cargó ningún documento")
        return None

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=900,
        chunk_overlap=120,
        separators=[
            "\n## ",
            "\n---\n",
            "\n\n",
            "\n",
            ". ",
            " "
        ]
    )

    chunks = splitter.split_documents(docs)
    print(f"Chunks generados: {len(chunks)}")
    print("Generando embeddings...")

    if os.path.exists(VECTOR_LOCAL):
        shutil.rmtree(VECTOR_LOCAL)
    os.makedirs(VECTOR_LOCAL, exist_ok=True)

    vs = Chroma.from_documents(
        documents=chunks,
        embedding=emb,
        persist_directory=VECTOR_LOCAL
    )

    if os.path.exists(VECTOR_DRIVE):
        shutil.rmtree(VECTOR_DRIVE)
    shutil.copytree(VECTOR_LOCAL, VECTOR_DRIVE)

    print(f"{len(chunks)} chunks indexados")
    print("Backup guardado en Drive")
    return vs

def load_vectorstore():
    if not os.path.exists(VECTOR_LOCAL) or not os.listdir(VECTOR_LOCAL):
        print("Restaurando vectorstore desde Drive...")
        if os.path.exists(VECTOR_DRIVE) and os.listdir(VECTOR_DRIVE):
            shutil.copytree(VECTOR_DRIVE, VECTOR_LOCAL, dirs_exist_ok=True)
            print("Restaurado en disco local")
        else:
            print("Sin backup en Drive. Re-indexando...")
            return build_vectorstore()

    return Chroma(
        persist_directory=VECTOR_LOCAL,
        embedding_function=emb
    )

drive_ok = os.path.exists(os.path.join(VECTOR_DRIVE, "chroma.sqlite3"))

if drive_ok:
    shutil.copytree(VECTOR_DRIVE, VECTOR_LOCAL, dirs_exist_ok=True)
    total = sum(c.count() for c in chromadb.PersistentClient(path=VECTOR_LOCAL).list_collections())
    print(f"Vectorstore en Drive: {total} documentos")
    vectorstore = load_vectorstore() if total > 0 else build_vectorstore()
else:
    print("Sin vectorstore previo: indexando desde cero...")
    vectorstore = build_vectorstore()
# Out:
# Vectorstore en Drive: 29281 documentos

# %%
retriever = vectorstore.as_retriever(
    search_type="mmr",
    search_kwargs={"k": 8, "fetch_k": 20, "lambda_mult": 0.7}
)

print("Retriever listo")

query = "autonomía de la voluntad contrato civil"
test = retriever.invoke("query: " + query)
print(f"Test: {len(test)} fragmentos recuperados\n")

for i, r in enumerate(test, 1):
    tipo = r.metadata.get("tipo", "?")
    cat = r.metadata.get("categoria", "?")
    art = r.metadata.get("num_articulo", "-")
    pag = r.metadata.get("page", "-")
    preview = r.page_content[:220].replace("\n", " ")
    print(f"{i}. {tipo} | {cat} | art={art} | pag={pag}")
    print(preview)
    print()
# Out:
# Retriever listo
# Test: 8 fragmentos recuperados
#
# 1. sentencia | Sentencias | art=- | pag=27
# passage: Radicación: 73001-31-10-002-2014-00340-01  «( ... ) la autonomía privada en cuanto libertad contractual,  comporta el razonable reconocimiento legal a toda persona de un  cúmulo de poderes o facultades proyectad
#
# 2. sentencia | Sentencias | art=- | pag=26
# De ahí que, con contu ndencia, sentencie el artículo  1502 del Código Civil, que en orden a que «una persona se  obligue a otra por un acto o declaración de voluntad », resulta  indispensable que el declarante «consienta
#
# 3. sentencia | Sentencias | art=- | pag=42
# si, trasciende al mero arbitrio o a la simple volición19" »  (CSJ 4902-2019, 13 nov.)  11 <<SPOTA, AG. Instituciones de Derecho Civil. Contratos. T /// Pág. 516» (referencia propia del  texto citado).
#
# 4. sentencia | Sentencias | art=- | pag=21
# condición de obedecer los dictados de la razón, el sinónimo  de libertad que en ella encontró Rosseau como la posibilidad  de elegir y valorar, dieron sólidas bases al entendimiento de  la relación jurídica negocial como
#
# 5. sentencia | Sentencias | art=- | pag=29
# infiere la falla sanitaria a partir de la ausencia de un  resultado, cuando los galenos se han comprometido a  alcanzar este último en aplicación de la libre autonomía de  la voluntad, como lo ha asegurado este órgano de
#
# 6. sentencia | Sentencias | art=- | pag=20
# Acorde con ello, puede afirmarse que las solemnidades  testamentarias no han sido instituidas como mera  formalidad, sino como mecanismo de protección del proceso  de formación de la voluntad , de la emisión del  consent
#
# 7. sentencia | Sentencias | art=- | pag=24
# 7 Dice la sentencia: «Desde la ciencia del d erecho civil alemán de la primera mitad del siglo XIX, el  negocio jurídico (rechtsgeschaft) ha sido definido como una declaración de la voluntad explícita o  resultante de un
#
# 8. sentencia | Sentencias | art=- | pag=85
# incumplimiento haya cumplido sus propias obligaciones  contractuales En el caso, el mutuo disenso se fundamenta en el  principio de la autonomia de voluntad de las partes  consagrado en el articulo 1255 del Codigo Civil

# %%
def format_docs(docs):
    bloques = []

    for d in docs:
        tipo = d.metadata.get("tipo", "?")
        categoria = d.metadata.get("categoria", "?")
        fuente = d.metadata.get("fuente", "?")

        if tipo == "norma":
            ley = d.metadata.get("ley", "?")
            art = d.metadata.get("num_articulo", "?")
            encabezado = d.metadata.get("encabezado", "")
            cabecera = f"[NORMA | {categoria} | Ley {ley} | Artículo {art} | {fuente}]"
            if encabezado:
                cabecera += f"\n{encabezado}"
        else:
            pagina = d.metadata.get("page", "?")
            cabecera = f"[SENTENCIA | {categoria} | {fuente} | página {pagina}]"

        contenido = d.page_content.replace("passage: ", "", 1)
        bloques.append(f"{cabecera}\n{contenido}")

    return "\n\n---\n\n".join(bloques)

print("format_docs listo")
# Out:
# format_docs listo

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from google.colab import userdata

GEMINI_API_KEY = userdata.get("Gemini_API_Key")

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=GEMINI_API_KEY,
    temperature=0,
)

RAG_PROMPT = ChatPromptTemplate.from_template("""
Eres un sistema de recuperación de información jurídica.
Tu única función es leer el CONTEXTO y responder con base EXCLUSIVA en él.

REGLAS ESTRICTAS:
1. SOLO puedes usar información que aparezca literalmente en el CONTEXTO.
2. Si la respuesta no está en el CONTEXTO, responde exactamente:
   "No encontrado en el corpus. El contexto recuperado no contiene información suficiente para responder."
3. PROHIBIDO usar conocimiento jurídico propio, pre-entrenamiento o inferencias externas al CONTEXTO.
4. PROHIBIDO completar, inferir o extrapolar más allá de lo que dice el texto recuperado.
5. Cita siempre el artículo, sentencia o fuente exacta que usaste del CONTEXTO.

CONTEXTO RECUPERADO:
{context}

PREGUNTA:
{question}

RESPUESTA (basada únicamente en el contexto de arriba):
""")

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | RAG_PROMPT
    | llm
    | StrOutputParser()
)

print("✅ Gemini 2.5 Flash (pago) listo — sin límite diario")
# Out:
# ✅ Gemini 2.5 Flash (pago) listo — sin límite diario

# %%
rag_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough()
    }
    | RAG_PROMPT
    | llm
    | StrOutputParser()
)

print("Cadena RAG lista")
# Out:
# Cadena RAG lista

# %%
pregunta = "¿Qué dice la Ley 1480 sobre el derecho de retracto?"
respuesta = rag_chain.invoke("query: " + pregunta)

print("PREGUNTA:\n", pregunta)
print("\nRESPUESTA:\n", respuesta)
# Out:
# PREGUNTA:
#  ¿Qué dice la Ley 1480 sobre el derecho de retracto?
#
# RESPUESTA:
#  Según la Ley 1480, en su Artículo 47, se entenderá pactado el derecho de retracto por parte del consumidor en todos los contratos para la venta de bienes y prestación de servicios mediante sistemas de financiación otorgada por el productor o proveedor, venta de tiempos compartidos o ventas que utilizan métodos no tradicionales o a distancia, que por su naturaleza no deban consumirse o no hayan comenzado a ejecutarse antes de cinco (5) días. En caso de hacer uso de esta facultad, el contrato se resolverá y se deberá reintegrar el dinero que el consumidor hubiese pagado.
#
# Cita: [NORMA | Ley_1480 | Ley 1480 | Artículo 47 | ley_1480_rag]

# %%
pregunta = "¿Cuáles son los vicios del consentimiento?"
docs = retriever.invoke("query: " + pregunta)

print(f"Chunks recuperados: {len(docs)}\n")

for d in docs:
    print(
        "-",
        d.metadata.get("tipo"),
        "|",
        d.metadata.get("categoria"),
        "| art:",
        d.metadata.get("num_articulo", "-"),
        "| pág:",
        d.metadata.get("page", "-")
    )
    print(d.page_content[:180])
    print()
# Out:
# Chunks recuperados: 8
#
# - norma | Codigo_Civil | art: 1508 | pág: -
# passage: # Codigo_Civil — Extracto para RAG
# > Generado el 2026-06-18 23:49
#
# Artículo 1508
# ARTÍCULO 1508. <VICIOS DEL CONSENTIMIENTO>. Los vicios de que puede adolecer el consentimi
#
# - sentencia | Sentencias | art: - | pág: 29
# afectada por irregularidades que genéricamente son denominadas en la ley y en la doctrina vicios del
# consentimiento, los cuales son error, fuerza y dolo. La fuerza o violencia es
#
# - norma | Codigo_Comercio | art: 107 | pág: -
# passage: # Codigo_Comercio — Extracto para RAG
# > Generado el 2026-06-18 23:51
#
# Artículo 107
# ARTÍCULO 107. <ERROR DE HECHO, ERROR SOBRE LA ESPECIE DE SOCIEDAD - VICIO DEL CONSENTIMI
#
# - sentencia | Sentencias | art: - | pág: 29
# extracción y preferencia de la negociación real que  se
# escondió bajo el ropaje de una declaración fingida. La
# utilidad reparadora, por su parte, aparece en la medida en
# que la
#
# - sentencia | Sentencias | art: - | pág: 26
# De ahí que, con contu ndencia, sentencie el artículo
# 1502 del Código Civil, que en orden a que «una persona se
# obligue a otra por un acto o declaración de voluntad », resulta
# in
#
# - sentencia | Sentencias | art: - | pág: 34
# ausencia de vicio por error espontáneo o provocado, dolo, fuerza,
# estado de necesidad o de peligro. Asimismo, la estipulación
# dispositiva en forma alguna debe configurar ejercici
#
# - sentencia | Sentencias | art: - | pág: 15
# por su propia naturaleza o destino, aunque se las suponga
# de la más perfecta calidad en su especie.» (Inc. 2°, art. 1104,
# C. Co. Resaltó la Sala).
# Así las cosas, en materia merc
#
# - sentencia | Sentencias | art: - | pág: 76
# Corral, Barcelona: Jaime Molinas Editor, Consejo de ciento, No. 287, 1889, Libro 3,
# Titulo 29, p. 123, texto segun el cual “Ademds de esto, las obligaciones que se contraen
# por e

# %%
class AgentState(TypedDict):
    pregunta: str
    contexto: str
    borrador: str
    feedback: str
    respuesta_final: str
    num_revisiones: int

print("Estado del agente definido")
# Out:
# Estado del agente definido

# %%
cot_prompt = ChatPromptTemplate.from_template("""
Eres un experto jurista en Derecho Contractual Civil Colombiano.
Tu tarea es responder a la PREGUNTA basándote ÚNICAMENTE en el CONTEXTO RECUPERADO.

Si recibes FEEDBACK DE AUDITORÍA, úsalo para corregir tu error anterior.

INSTRUCCIONES DE RAZONAMIENTO:
Estructura tu respuesta siguiendo este silogismo:
1. PREMISA MAYOR: Norma o jurisprudencia aplicable.
2. PREMISA MENOR: Análisis del caso/pregunta.
3. CONCLUSIÓN: Respuesta final.

CONTEXTO RECUPERADO: {contexto}
PREGUNTA: {pregunta}
FEEDBACK DE AUDITORÍA (Si existe): {feedback}

SILOGISMO JURÍDICO:
""")

cov_prompt = ChatPromptTemplate.from_template("""
Eres un Auditor Jurídico implacable. Tu tarea es evaluar la fidelidad jurídica de un BORRADOR frente a un CONTEXTO.

REGLAS:
1. ¿El borrador cita leyes o sentencias que NO están en el contexto?
2. ¿La conclusión contradice el contexto?

INSTRUCCIONES DE SALIDA:
- Si el borrador es 100% fiel al contexto, responde única y exclusivamente con:
[APROBADO]
y luego el texto exacto del borrador.
- Si detectas error, responde comenzando exactamente con:
[RECHAZADO]
y explica con claridad el problema.

CONTEXTO RECUPERADO: {contexto}
BORRADOR DE RESPUESTA: {borrador}

AUDITORÍA FINAL:
""")

print("Prompts agénticos listos")
# Out:
# Prompts agénticos listos

# %%
def nodo_recuperador(state: AgentState):
    print("Ejecutando: Recuperación de documentos...")
    docs = retriever.invoke("query: " + state["pregunta"])
    contexto_formateado = format_docs(docs)
    return {"contexto": contexto_formateado, "num_revisiones": 0, "feedback": ""}

def nodo_razonador(state: AgentState):
    print(f"Ejecutando: Agente Razonador (Intento {state['num_revisiones'] + 1})...")
    chain = cot_prompt | llm | StrOutputParser()
    borrador = chain.invoke({
        "contexto": state["contexto"],
        "pregunta": state["pregunta"],
        "feedback": state["feedback"]
    })
    return {"borrador": borrador, "num_revisiones": state["num_revisiones"] + 1}

def nodo_verificador(state: AgentState):
    print("Ejecutando: Agente Verificador (Auditoría)...")
    chain = cov_prompt | llm | StrOutputParser()
    evaluacion = chain.invoke({
        "contexto": state["contexto"],
        "borrador": state["borrador"]
    })

    if "[APROBADO]" in evaluacion:
        respuesta_limpia = evaluacion.replace("[APROBADO]", "").strip()
        return {"feedback": evaluacion, "respuesta_final": respuesta_limpia}
    else:
        return {"feedback": evaluacion}

def decidir_siguiente_paso(state: AgentState):
    if "[APROBADO]" in state["feedback"]:
        print("Auditoría superada. Finalizando.")
        return "fin"
    elif state["num_revisiones"] >= 3:
        print("Límite de revisiones alcanzado. Entregando el último borrador.")
        return "fin"
    else:
        print(f"Error detectado: {state['feedback'][:60]}... Devolviendo al Razonador.")
        return "revisar"

print("Nodos del grafo listos")
# Out:
# Nodos del grafo listos

# %%
workflow = StateGraph(AgentState)

workflow.add_node("Recuperador", nodo_recuperador)
workflow.add_node("Razonador", nodo_razonador)
workflow.add_node("Verificador", nodo_verificador)

workflow.set_entry_point("Recuperador")
workflow.add_edge("Recuperador", "Razonador")
workflow.add_edge("Razonador", "Verificador")

workflow.add_conditional_edges(
    "Verificador",
    decidir_siguiente_paso,
    {
        "fin": END,
        "revisar": "Razonador"
    }
)

app_agentica = workflow.compile()

print("Arquitectura agéntica compilada exitosamente")
# Out:
# Arquitectura agéntica compilada exitosamente

# %%
pregunta_test = "¿Cuáles son los vicios del consentimiento según la normativa colombiana?"
resultado = app_agentica.invoke({"pregunta": pregunta_test})

print("\n" + "="*50)
print("RESPUESTA FINAL DEL SISTEMA AGÉNTICO")
print("="*50)
print(resultado["respuesta_final"] if "respuesta_final" in resultado else resultado["borrador"])
# Out:
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
#
# ==================================================
# RESPUESTA FINAL DEL SISTEMA AGÉNTICO
# ==================================================
# BORRADOR DE RESPUESTA: SILOGISMO JURÍDICO:
#
# 1.  **PREMISA MAYOR:** Según el Artículo 1508 del Código Civil colombiano, los vicios de que puede adolecer el consentimiento son el error, la fuerza y el dolo. Esta clasificación es reiterada por la jurisprudencia de la Corte Suprema de Justicia (Sentencia SC5040-2021), que los describe como irregularidades que afectan la manifestación de voluntad, exigiendo que esta sea consciente y libre. La misma jurisprudencia define el error como la falta de correspondencia entre la representación mental del sujeto y la realidad, la fuerza como la presión física o moral que infunde miedo para obtener el consentimiento, y el dolo como todo artificio para engañar que induce o provoca un error.
#
# 2.  **PREMISA MENOR:** La pregunta solicita identificar los vicios del consentimiento conforme a la normativa colombiana. El contexto recuperado proporciona directamente la enumeración de estos vicios tanto en la ley sustantiva como en la interpretación jurisprudencial.
#
# 3.  **CONCLUSIÓN:** De acuerdo con la normativa civil colombiana, los vicios del consentimiento son el error, la fuerza y el dolo.

# %%
def cargar_preguntas(ruta_archivo):
    print(f"Cargando preguntas desde: {ruta_archivo}")
    with open(ruta_archivo, "r", encoding="utf-8") as f:
        contenido = f.read()

    preguntas = re.findall(r'^\d+\.\s+(.*)', contenido, re.MULTILINE)
    print(f"Total de preguntas extraídas: {len(preguntas)}")
    return preguntas

print("Función cargar_preguntas lista")
# Out:
# Función cargar_preguntas lista

# %%
def ejecutar_evaluacion_comparativa(preguntas):
    resultados = []

    print("\nIniciando ejecución masiva. Esto puede tardar varios minutos...")

    for i, pregunta in enumerate(tqdm(preguntas, desc="Procesando preguntas"), 1):
        fila = {
            "ID_Pregunta": i,
            "Pregunta": pregunta,
            "Respuesta_RAG_Base": "",
            "Respuesta_Agente_CoT_CoV": "",
            "Num_Revisiones_Agente": 0,
            "Error": ""
        }

        try:
            respuesta_base = rag_chain.invoke("query: " + pregunta)
            fila["Respuesta_RAG_Base"] = respuesta_base

            time.sleep(1)

            estado_inicial = {"pregunta": pregunta, "num_revisiones": 0}
            resultado_agente = app_agentica.invoke(estado_inicial)

            if "respuesta_final" in resultado_agente:
                fila["Respuesta_Agente_CoT_CoV"] = resultado_agente["respuesta_final"]
            else:
                fila["Respuesta_Agente_CoT_CoV"] = f"[No Aprobado tras revisiones] {resultado_agente.get('borrador', '')}"

            fila["Num_Revisiones_Agente"] = resultado_agente.get("num_revisiones", 0)

        except Exception as e:
            fila["Error"] = str(e)
            print(f"\nError en la pregunta {i}: {e}")

        resultados.append(fila)

    return resultados

# %%
def guardar_resultados(resultados, ruta_salida):
    df = pd.DataFrame(resultados)
    df.to_csv(ruta_salida, index=False, encoding='utf-8-sig')
    print(f"\n¡Evaluación terminada! Resultados guardados en: {ruta_salida}")
    return df

print("Función guardar_resultados lista")
# Out:
# Función guardar_resultados lista

# %%
RUTA_GOLDEN_SET = "/content/drive/MyDrive/TG_Maestria/04_Golden_Set/golden_set.md"
RUTA_RESULTADOS = "/content/drive/MyDrive/TG_Maestria/03_Results/resultados_comparativos.csv"

lista_preguntas = cargar_preguntas(RUTA_GOLDEN_SET)

# Prueba pequeña
#resultados_raw = ejecutar_evaluacion_comparativa(lista_preguntas[:5])

# Lote completo
resultados_raw = ejecutar_evaluacion_comparativa(lista_preguntas)

df_resultados = guardar_resultados(resultados_raw, RUTA_RESULTADOS)
df_resultados.head()
# Out:
# Cargando preguntas desde: /content/drive/MyDrive/TG_Maestria/04_Golden_Set/golden_set.md
# Total de preguntas extraídas: 120
#
# Iniciando ejecución masiva. Esto puede tardar varios minutos...
# Procesando preguntas:   0%|          | 0/120 [00:00<?, ?it/s]
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador introduce en su conclusión el "crite... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador no es 100% fiel al contexto recupera... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# La Premisa Menor y la Conclusión introducen la c... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador introduce el concepto de "culpa grav... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador no es 100% fiel al contexto recupera... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
#
# Error en la pregunta 25: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# La conclusión contradice el contexto en la formu... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# La conclusión del borrador contradice el context... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# La Premisa Menor y la Conclusión del borrador af... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador, específicamente en su Premisa Menor... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador presenta dos problemas de fidelidad ... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador no es 100% fiel al contexto. En la P... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador no es 100% fiel al contexto recupera... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# La Premisa Menor y la Conclusión del borrador in... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# La Premisa Menor del borrador introduce un escen... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador no es 100% fiel al contexto. La Prem... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Error detectado: [RECHAZADO]
# El borrador no es 100% fiel al contexto recupera... Devolviendo al Razonador.
# Ejecutando: Agente Razonador (Intento 2)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
#
# Error en la pregunta 114: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
#
# Error en la pregunta 119: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# Ejecutando: Recuperación de documentos...
# Ejecutando: Agente Razonador (Intento 1)...
# Ejecutando: Agente Verificador (Auditoría)...
# Auditoría superada. Finalizando.
#
# ¡Evaluación terminada! Resultados guardados en: /content/drive/MyDrive/TG_Maestria/03_Results/resultados_comparativos.csv
#    ID_Pregunta                                           Pregunta  \
# 0            1  En un contrato de compraventa civil celebrado ...
# 1            2  Si dos partes pactan verbalmente la modificaci...
# 2            3  ¿Cómo debe interpretarse una cláusula penal pa...
# 3            4  En un contrato de prestación de servicios civi...
# 4            5  ¿Puede considerarse perfeccionado un contrato ...
#
#                                   Respuesta_RAG_Base  \
# 0  Para reconstruir la intención común de las par...
# 1  No encontrado en el corpus. El contexto recupe...
# 2  Cuando la redacción de una cláusula penal en u...
# 3  No encontrado en el corpus. El contexto recupe...
# 4  Si la voluntad de los interesados es "disímil ...
#
#                             Respuesta_Agente_CoT_CoV  Num_Revisiones_Agente  \
# 0  SILOGISMO JURÍDICO:\n\n1.  **PREMISA MAYOR:**\...                      2
# 1  SILOGISMO JURÍDICO:\n\n1.  **PREMISA MAYOR:**\...                      1
# 2  SILOGISMO JURÍDICO:\n\n1.  **PREMISA MAYOR**:\...                      1
# 3  El contexto recuperado no contiene información...                      1
# 4  SILOGISMO JURÍDICO:\n\n1.  **PREMISA MAYOR:**\...                      1
#
#   Error
# 0
# 1
# 2
# 3
# 4
